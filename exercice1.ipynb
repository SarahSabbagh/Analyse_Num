# %% [markdown]
# # Tp 1

# %% [markdown]
# ## Exercice 1:
# On considère le polynôme  𝑝(𝑥)=(𝑥−1)6 .
#
# En développant on peut écrire ce même polynôme sous la forme  𝑓(𝑥)=𝑥6−6𝑥5+15𝑥4−20𝑥3+15𝑥2−6𝑥+1.
# 1) Avec Matlab évaluer  𝑝(𝑥)  et  𝑓(𝑥)  pour  𝑥  allant de  .998  à  1.002  en choisissant des pas de  .0001 .

# %%
def p(x) :
    """"définir la fonction 𝑝(𝑥)=(𝑥−1)6 """
    return (x-1)**6
def f(x) :
    """"définir la fonction  𝑓(𝑥)=𝑥6−6𝑥5+15𝑥4−20𝑥3+15𝑥2−6𝑥+1"""
    return x**6-6*x**5+15*x**4-20*x**3+15*x**2-6*x+1

# %%
import numpy as np

for i in np.arange(0.998,1.002,0.0001):
    print("-f(",i,")=",f(i))
    print("-p(",i,")=",p(i))
# Out:
# -f( 0.998 )= 1.7763568394002505e-15
# -p( 0.998 )= 6.400000000000034e-17
# -f( 0.9981 )= 1.7763568394002505e-15
# -p( 0.9981 )= 4.70458810000019e-17
# -f( 0.9982 )= 0.0
# -p( 0.9982 )= 3.40122240000027e-17
# -f( 0.9983 )= -2.6645352591003757e-15
# -p( 0.9983 )= 2.4137569000002966e-17
# -f( 0.9984 )= 1.7763568394002505e-15
# -p( 0.9984 )= 1.6777216000002883e-17
# -f( 0.9984999999999999 )= 0.0
# -p( 0.9984999999999999 )= 1.139062500000259e-17
# -f( 0.9985999999999999 )= -1.7763568394002505e-15
# -p( 0.9985999999999999 )= 7.52953600000219e-18
# -f( 0.9986999999999999 )= 8.881784197001252e-16
# -p( 0.9986999999999999 )= 4.826809000001757e-18
# -f( 0.9987999999999999 )= 1.7763568394002505e-15
# -p( 0.9987999999999999 )= 2.985984000001342e-18
# -f( 0.9988999999999999 )= -3.552713678800501e-15
# -p( 0.9988999999999999 )= 1.771561000000975e-18
# -f( 0.9989999999999999 )= 0.0
# -p( 0.9989999999999999 )= 1.0000000000006715e-18
# -f( 0.9990999999999999 )= -2.6645352591003757e-15
# -p( 0.9990999999999999 )= 5.314410000004355e-19
# -f( 0.9991999999999999 )= 0.0
# -p( 0.9991999999999999 )= 2.6214400000026335e-19
# -f( 0.9992999999999999 )= 0.0
# -p( 0.9992999999999999 )= 1.1764900000014617e-19
# -f( 0.9993999999999998 )= -1.7763568394002505e-15
# -p( 0.9993999999999998 )= 4.665600000007277e-20
# -f( 0.9994999999999998 )= -8.881784197001252e-16
# -p( 0.9994999999999998 )= 1.562500000003131e-20
# -f( 0.9995999999999998 )= 0.0
# -p( 0.9995999999999998 )= 4.096000000010936e-21
# -f( 0.9996999999999998 )= 1.7763568394002505e-15
# %%
import numpy as np
import matplotlib.pyplot as plt 
#Cf ,Cp = plt.subplots()
x=np.linspace(0.998,1.002,40)
plt.plot(x,p(x))
plt.plot(x,f(x))
plt.title('solution dans [0.998,1.002]')
plt.show()

# %% [markdown]
# !!!!!!!

# %% [markdown]
# ## EXERCICE 2:
# On considère l'équation :
# 𝑓(𝑥)=𝑥3+𝑥2−3𝑥−3=0
#
# 1) Dessiner la courbe de  𝑓  dans l'intervalle  [−2;2] , puis trouver des intervalles convenables pour appliquer la méthode de >bisection.
#
# 2) Utiliser un programme dicho.m qui permettra de trouver les solutions de l'équation  𝑓(𝑥)=0  avec  𝑒𝑝𝑠=0.001 .
#
# 3) Modifier le programme dicho.m pour qu'il donne le nombre d'itération nécessaire pour avoir la solution à  𝑒𝑝𝑠  près.

# %%
import numpy as np
import matplotlib.pyplot as plt 
x=np.linspace(-2,2,40)
g=lambda x: x**3+x**2-3*x-3
plt.plot(x,g)
plt.title('solution dans [-2,2]')
plt.show()

# %% [markdown]
# Daprés le graph de  𝑓  il existe 3 solutions :
# 𝛼1∈]−2;−1.5[
# 𝛼2∈]−1.5;−0.5[
# 𝛼3∈]1.5;2[

# %%
def dicho(a,b,g,tol):
    '''version itérative '''
    m=(a+b)/2
    err=abs(b-a)
    while err>tol :
        if g(m)==0 :
            break
        elif g(a)*g(m)<0 :
            b=m
        else: a=m
        m=(a+b)/2
        err=abs(b-a)
    return m

# %%
x3=dicho(-2,-1.5,g,10)
x10=dicho(-2,-1.5,f,10)
x20=dicho(-2,-1.5,f,20)
#print(x3,x10,x20)
print(x3)
# Out:
# -1.75

# %%
def dichow(a,b,f,eps):
    """version tant que qui renvoila solution avec le nombre d'''itération """
    m=(a+b)/2
    err=abs(b-a)
    n=0
    while err>eps :
        n+=1
        if f(m)==0 :
            break
        elif f(a)*f(m)<0 :
            b=m
        else: a=m
        m=(a+b)/2
        err=abs(b-a)
    return m,n

# %%
import numpy as np
np.floor(2.3)
np.ceil(2.3)
# Out:
# 3.0

# %%
import numpy as np
a=-1.5
b=-0.5
p=8 # précision à 10 ^-8 prés
dichow(a,b,f,10**(-p))
#à 10^-8
# Out:
# (-0.5000000037252903, 27)

# %%
interval=[[-2,-1.5],[-1.5,-0.5],[1.5,2]]
for u in interval:
    print(dichow(u[0],u[1],f,10**(-3)))
################################################   
print(dichow(-2,-1.5,f,10**(-3)))
print(dichow(-1.5,-0.5,f,10**(-3)))
print(dichow(1.5,2,f,10**(-3)))
# Out:
# (-1.50048828125, 9)
# (-0.50048828125, 10)
# (1.99951171875, 9)
# (-1.50048828125, 9)
# (-0.50048828125, 10)
# (1.99951171875, 9)
